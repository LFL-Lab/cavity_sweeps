# %%
from utils import *
from objects import *
from sweeper_helperfunctions import *

# %%
design = metal.designs.design_planar.DesignPlanar()
gui = metal.MetalGUI(design)
design.overwrite_enabled = True

# %%
cpw_sweep_opts = Dict(
                fillet = '49.9um',
                total_length = [f"{i * 500 + 1700}um" for i in range(15)],
                trace_width = "11.7um",
                trace_gap = '5.1um')

# %%
claw_sweep_opts = dict(
    connection_pads=dict(
        readout = dict(connector_location = '90', 
                 connector_type = '0', 
                 claw_length = '215um',
                 ground_spacing = '10um', 
                 claw_gap = '5.1um', 
                 claw_width = [f"{i * 2 + 7}um" for i in range(12)],
                 claw_cpw_width = "11.7um",
                 claw_cpw_length = '0um'
                 ),
    ),
    cross_width = '30um',
    cross_length = '240um',
    cross_gap = '30um',
)

# %%
generic_cplr_opts = Dict(prime_width = "11.7um",
            prime_gap = '5.1um',
            second_width = "11.7um",
            second_gap = '5.1um',
            coupling_space = '7.9um',
            coupling_length = '225um',
            open_termination = False,
            down_length = '50um')

# %%
sweep_opts = Dict(claw_opts = claw_sweep_opts, cpw_opts = cpw_sweep_opts, cplr_opts = generic_cplr_opts)

# %%
NCap_epr_sweep(design, sweep_opts = sweep_opts)
# Out:
# INFO 04:27PM [connect_project]: Connecting to Ansys Desktop API...
# INFO 04:27PM [load_ansys_project]: 	Opened Ansys App
# INFO 04:27PM [load_ansys_project]: 	Opened Ansys Desktop v2021.1.0
# INFO 04:27PM [load_ansys_project]: 	Opened Ansys Project
# 	Folder:    D:/Users/lfl/Documents/Ansoft/
# 	Project:   Project9
# INFO 04:27PM [connect_design]: 	Opened active design
# 	Design:    CavitySweep_hfss [Solution type: Eigenmode]
# INFO 04:27PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# INFO 04:27PM [connect]: 	Connected to project "Project9" and design "CavitySweep_hfss" 😀
# Starting the Simulation
# INFO 04:27PM [connect_design]: 	Opened active design
# 	Design:    CavitySweep8 [Solution type: Eigenmode]
# WARNING 04:27PM [connect_setup]: 	No design setup detected.
# WARNING 04:27PM [connect_setup]: 	Creating eigenmode default setup.
# INFO 04:27PM [get_setup]: 	Opened setup `Setup`  (<class 'pyEPR.ansys.HfssEMSetup'>)
# ...
